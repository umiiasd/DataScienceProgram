# %% [markdown]
# # HEART DISEASE PREDICTION

# %% [markdown]
# 1. age: person's age
# 2. sex: person's Gender
# 3. cp: Chest pain of four types (1-4)
# 4. trestbps: Person's Resting Blood Pressure
# 5. chol: Cholestrole level
# 6. fbs: fasting blood sugar level (0-2)
# 7. restecg (0-2)
# 8. thalach: maximum heart rate achieved
# 9. exang
# 10. oldpeak
# 11. slope
# 12. ca
# 13. thal (3: Normal, 6=Fixed, 7 = reversable defect)  #that means disease that is thalasemia
# 14. target: 0=No heart disease - 1 = Yes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("datasets/heart.csv")

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()  #minimum age person is 29 and maximum age is 77 but most people(average age) is 54 age
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.hist(figsize=(30,30)) #hist is used for draw histigram and figsize use for size of plot
  #in graph x-axis shows age values in age column and y-axis shows how many person appear in particular age
plt.show()

# %%
#set font of plot for easily view it usong sns.set() to icrease the size of font
sns.set(font_scale=2)
df.hist(figsize=(30,30))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'cp'}>,
#         <AxesSubplot:title={'center':'trestbps'}>],
#        [<AxesSubplot:title={'center':'chol'}>,
#         <AxesSubplot:title={'center':'fbs'}>,
#         <AxesSubplot:title={'center':'restecg'}>,
#         <AxesSubplot:title={'center':'thalach'}>],
#        [<AxesSubplot:title={'center':'exang'}>,
#         <AxesSubplot:title={'center':'oldpeak'}>,
#         <AxesSubplot:title={'center':'slope'}>,
#         <AxesSubplot:title={'center':'ca'}>],
#        [<AxesSubplot:title={'center':'thal'}>,
#         <AxesSubplot:title={'center':'target'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df['target'].value_counts()  #tell 0 and 1 value appear in target columns
#1 shows patient of heart disease and 0 shows no heart disease
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
df['target'].count()  #tell total values 0 and 1 appear in this column
# Out:
# 1025

# %%
sns.countplot(x='target',data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
df['sex'].value_counts()  #1 for male and 0 for female
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
sns.countplot(x='sex',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
df.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1         226
#      0          86
# 1    0         413
#      1         300
# Name: target, dtype: int64

# %%
sns.countplot(x='sex',hue='target',data=df) #gender ki bases py target check krna thats why use hue for target
#firstly group based on gender 0(female) and 1(male) then after that it divides into target of heart disease
# x = sex means plot of gender and then after it divide into female heart disease patients or not 
#and male heart disease patients or not
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
df.groupby('age')['target'].value_counts()
# Out:
# age  target
# 29   1          4
# 34   1          6
# 35   1          8
#      0          7
# 37   1          6
#                ..
# 70   1          3
# 71   1         11
# 74   1          3
# 76   1          3
# 77   0          3
# Name: target, Length: 75, dtype: int64

# %%
sns.countplot(x='age',hue='target',data=df) #set figyure size because its very complex showing
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
plt.figure(figsize=(30,10)) # first used for width and second is used for height
sns.countplot(x='age',hue='target',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %% [markdown]
# #### enumerate command of python

# %%
a = ['eat', 'sleep', 'repeat']

ans = enumerate(a) #Get the element and index(by default start from 0) from a list. and show output in tuple(index,element)

print(list(ans))
# Out:
# [(0, 'eat'), (1, 'sleep'), (2, 'repeat')]

# %%
b = "UmarRimsha"
ans = enumerate(b, 100) #assign index=100 is the first element index of variable b
print(list(ans))
# Out:
# [(100, 'U'), (101, 'm'), (102, 'a'), (103, 'r'), (104, 'R'), (105, 'i'), (106, 'm'), (107, 's'), (108, 'h'), (109, 'a')]

# %%
print(df.columns) #columns of dataset
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
print(list(df.columns)) #convert columns into list
# Out:
# ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']

# %%
categorical_values = list(df.columns)
categorical_values
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal',
#  'target']

# %%
#remove target column in this list
categorical_values.remove('target')

# %%
categorical_values
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal']

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
plt.figure(figsize=(30,30))
for i,col in enumerate(categorical_values,1):  #i use for index and col use for elements of all columns in datasets 
    plt.subplot(4,4,i)  #4 rows 4 columns i use for plot 1,2,3, upto so on depends on column in data set whoch have numeric values
    sns.barplot(x=f"{col}",y='target', data=df) #x=f"{col}" means get element in x-axis and 
    #y-axis is target to take x and y axis from df datasets"
    #f"{col}" use for format string and pass variable in that brackets for taking values
    plt.ylabel("Possibility of having Heart Disease")
    plt.xlabel(f"{col}")
