# %%
#Read File ->use pandas library for data cleaning
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("datasets/netflix.csv")

# %%
data
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# ...

# %%
data.shape #rows and columns
# Out:
# (1000, 7)

# %%
data.head() #print first 5 rows
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
data.tail()   #print last 5 rows
# Out:
#                        title rating  \
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 995  for action/peril, some scary moments and brief...                 60
# 996                     for action and some rude humor                 60
# 997                             Suitable for all ages.                 35
# 998                             Suitable for all ages.                 35
# 999                                                NaN                 35
#
#      release year  user rating score  user rating size
# 995          2016               97.0                80
# 996          2016                NaN                81
# 997          2003                NaN                82
# 998          2013                NaN                82
# ...

# %%
data.head(n=10)  #n=10 means 10 rows and head means top rows->first 10 rows
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
# 6           Breaking Bad  TV-MA
# 7    The Vampire Diaries  TV-14
# 8       The Walking Dead  TV-MA
# 9    Pretty Little Liars  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
# 5  Parents strongly cautioned. May be unsuitable ...                 90
# 6  For mature audiences.  May not be suitable for...                110
# ...

# %%
data.tail(n=10)  #last 10 rows
# Out:
#                           title rating  \
# 990           My Animal Friends   TV-Y
# 991          Dawn of the Croods  TV-Y7
# 992  Alpha and Omega: Dino Digs   TV-G
# 993   Wiener Dog Internationals      G
# 994                    Pup Star      G
# 995                     The BFG     PG
# 996     The Secret Life of Pets     PG
# 997            Precious Puppies   TV-G
# 998                 Beary Tales   TV-G
# 999             Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 990                             Suitable for all ages.                 10
# 991             Suitable for children ages 7 and older                 41
# 992                             Suitable for all ages.                 35
# 993          General Audiences. Suitable for all ages.                 35
# 994          General Audiences. Suitable for all ages.                 35
# 995  for action/peril, some scary moments and brief...                 60
# ...

# %%
print(data.columns)
# Out:
# Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#        'user rating score', 'user rating size'],
#       dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1000 non-null   object
#  1   rating             1000 non-null   object
#  2   ratingLevel        941 non-null    object
#  3   ratingDescription  1000 non-null   int64
#  4   release year       1000 non-null   int64
#  5   user rating score  605 non-null    float64
#  6   user rating size   1000 non-null   int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %% [markdown]
# # PANDAS FUNCTION

# %% [markdown]
# LOC  #for label based selection
# ILOC #for index based selection

# %%
data.loc[(data.rating=="PG-13") | (data["release year"]==2011)]  #use or operator means anyone from both
# Out:
#                                                  title    rating  \
# 0                                         White Chicks     PG-13
# 14                                          The Hunter         R
# 66                                       One Tree Hill     TV-14
# 73                     Inside Russia's Toughest Prison     TV-14
# 114                              Friends with Benefits     TV-14
# 213                              Friends with Benefits     TV-14
# 250                                       The Waterboy     PG-13
# 251                         10 Things I Hate About You     PG-13
# 253                       How to Lose a Guy in 10 Days     PG-13
# 254                                   The Benchwarmers     PG-13
# 255                                            Step Up     PG-13
# 257                                           Twilight     PG-13
# 273                                       Mean Girls 2     PG-13
# ...

# %%
data.loc[(data.rating=="PG-13") & (data["release year"]==2011)]  #use and operator means both true
# Out:
#             title rating                                        ratingLevel  \
# 273  Mean Girls 2  PG-13  For some rude and suggestive material, and for...
# 322  Mean Girls 2  PG-13  For some rude and suggestive material, and for...
#
#      ratingDescription  release year  user rating score  user rating size
# 273                 80          2011                NaN                82
# 322                 80          2011                NaN                82

# %%
data.isnull().sum()  #get info about dataset which which value is null
# Out:
# title                  0
# rating                 0
# ratingLevel           59
# ratingDescription      0
# release year           0
# user rating score    395
# user rating size       0
# dtype: int64

# %%
data.notnull().sum()  #which column has no null values
# Out:
# title                1000
# rating               1000
# ratingLevel           941
# ratingDescription    1000
# release year         1000
# user rating score     605
# user rating size     1000
# dtype: int64

# %%
data.loc[(data.rating=="TV-14")]  #rating is TV-14
# Out:
#                    title rating  \
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 5           Supernatural  TV-14
# 7    The Vampire Diaries  TV-14
# 9    Pretty Little Liars  TV-14
# ..                   ...    ...
# 489             Rosewood  TV-14
# 491             Quantico  TV-14
# 492            Limitless  TV-14
# 495          No Tomorrow  TV-14
# 499            Greenleaf  TV-14
#
#                                            ratingLevel  ratingDescription  \
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 5    Parents strongly cautioned. May be unsuitable ...                 90
# 7    Parents strongly cautioned. May be unsuitable ...                 90
# 9    Parents strongly cautioned. May be unsuitable ...                 90
# ..                                                 ...                ...
# ...

# %%
data.loc[(data.rating=="TV-14") & (data["user rating score"]>=90)]  #rating is TV-14 and rating score is 90 or above
# Out:
#                    title rating  \
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 5           Supernatural  TV-14
# 7    The Vampire Diaries  TV-14
# 9    Pretty Little Liars  TV-14
# ..                   ...    ...
# 472   Person of Interest  TV-14
# 474              Scandal  TV-14
# 476             Sherlock  TV-14
# 477      The Client List  TV-14
# 483        The Blacklist  TV-14
#
#                                            ratingLevel  ratingDescription  \
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 5    Parents strongly cautioned. May be unsuitable ...                 90
# 7    Parents strongly cautioned. May be unsuitable ...                 90
# 9    Parents strongly cautioned. May be unsuitable ...                 90
# ..                                                 ...                ...
# ...

# %%
data.loc[(data.rating=="TV-14"),["title","ratingLevel","ratingDescription"]] #in pandas first is row  and second is column-->separate by comma of row/column
# Out:
#                    title                                        ratingLevel  \
# 2         Grey's Anatomy  Parents strongly cautioned. May be unsuitable ...
# 3           Prison Break  Parents strongly cautioned. May be unsuitable ...
# 5           Supernatural  Parents strongly cautioned. May be unsuitable ...
# 7    The Vampire Diaries  Parents strongly cautioned. May be unsuitable ...
# 9    Pretty Little Liars  Parents strongly cautioned. May be unsuitable ...
# ..                   ...                                                ...
# 489             Rosewood  Parents strongly cautioned. May be unsuitable ...
# 491             Quantico  Parents strongly cautioned. May be unsuitable ...
# 492            Limitless  Parents strongly cautioned. May be unsuitable ...
# 495          No Tomorrow  Parents strongly cautioned. May be unsuitable ...
# 499            Greenleaf  Parents strongly cautioned. May be unsuitable ...
#
#      ratingDescription
# 2                   90
# ...

# %%
data.loc[(data.rating=="TV-14"),["title","ratingLevel","ratingDescription"]].isnull().sum() #how many null values in new data
# Out:
# title                0
# ratingLevel          9
# ratingDescription    0
# dtype: int64

# %%
data.loc[(data.rating=="TV-14"),["title","ratingLevel","ratingDescription"]].shape
# Out:
# (234, 3)

# %% [markdown]
# # PANDAS--> ILOC(INDEX BASED SELECTION)

# %%
data.iloc[[0,2]]
# Out:
#             title rating                                        ratingLevel  \
# 0    White Chicks  PG-13  crude and sexual humor, language and some drug...
# 2  Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
#
#    ratingDescription  release year  user rating score  user rating size
# 0                 80          2004               82.0                80
# 2                 90          2016               98.0                80

# %%
data.iloc[[0,2],0:2]  #0,2 means 0 and 2 rows print and 0:2 for column start from 0 to 1 means first 2 column print
# Out:
#             title rating
# 0    White Chicks  PG-13
# 2  Grey's Anatomy  TV-14

# %%
data.iloc[0:3]  #start from 0 to 2 index means first 3 rows print
# Out:
#                  title rating  \
# 0         White Chicks  PG-13
# 1  Lucky Number Slevin      R
# 2       Grey's Anatomy  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80

# %%
data.iloc[0:3,0:-1]  #0:3 means 0 then 1 then 2 rows tk jaey and 0:-1 means start sy last tk except last column
# Out:
#                  title rating  \
# 0         White Chicks  PG-13
# 1  Lucky Number Slevin      R
# 2       Grey's Anatomy  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release year  user rating score
# 0          2004               82.0
# 1          2006                NaN
# 2          2016               98.0

# %%
data.describe()
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count         1000.00000   1000.000000         605.000000       1000.000000
# mean            67.36600   2010.335000          84.094215         80.783000
# std             30.78561      8.877927          12.344371          0.973066
# min             10.00000   1940.000000          55.000000         80.000000
# 25%             35.00000   2007.000000          75.000000         80.000000
# 50%             60.00000   2015.000000          88.000000         80.000000
# 75%             90.00000   2016.000000          95.000000         82.000000
# max            124.00000   2017.000000          99.000000         82.000000

# %% [markdown]
# # ONE-HOT-ENCODING TECHNIQUE

# %%
data
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# ...

# %%
data.isnull().sum()
# Out:
# title                  0
# rating                 0
# ratingLevel           59
# ratingDescription      0
# release year           0
# user rating score    395
# user rating size       0
# dtype: int64

# %%
a=data["user rating score"].mean()  # replace null values with mean value in specified column
a
# Out:
# 84.09421487603316

# %%
data.replace(to_replace=np.nan,value = a ,inplace = True) #np.nan means null value replace with value

# %%
data
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# ...
